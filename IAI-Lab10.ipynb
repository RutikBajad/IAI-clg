# %%
def chatbot():
    print("Chatbot: Hello, this is a simple rule-based chatbot.")
    greetings = {
        "hello": "Hi there!",
        "hi": "Hello!",
        "hey": "Hey! How are you?",
        "good morning": "Good morning! Hope you have a great day!",
        "good evening": "Good evening! How was your day?",
        "good night": "Good night! Sleep well!"
    }
    while True:
        user_input = input("You:").lower().strip()

        if user_input in ["exit", "quit", "bye"]:
            print("Chatbot: Goodbye! Have a great day.")
            break
        if user_input in greetings:
            print("Bot: ", greetings[user_input])
        else:
            print("I didn't understand that. Please greet me...")

# %%
chatbot()
# Out:
# Chatbot: Hello, this is a simple rule-based chatbot.
# You: hi
# Bot:  Hello!
# You: hello
# Bot:  Hi there!
# You: hey
# Bot:  Hey! How are you?
# You: good evening
# Bot:  Good evening! How was your day?
# You: good morninG
# Bot:  Good morning! Hope you have a great day!
