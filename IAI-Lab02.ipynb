# %%
import numpy as np
from scipy.stats import stats
import math

# %%
n = int(input("Enter N: "))
p = float(input("Enter P: "))
k = int(input("Enter no. of successes you are interested in: "))

def binomial_probability(n, p, k):
    combinations = math.comb(n, k)
    probability = combinations * (p ** k) * ((1 - p)**(n-k))
    return probability

print("\nBinomial distribution results:")
probabilities = []
for k in range(n+1):
    probability = binomial_probability(n, p, k)
    probabilities.append(probability)
    print(f"Heads: {i} | Probability: {probability:.6f}")

expected_heads = n*p
expected_tails = n*(1-p)

print(f"Expected Heads: {expected_heads}")
print(f"Expected Tails: {expected_tails}")
# Out:
# Enter N:  10
# Enter P:  0
# Enter no. of successes you are interested in:  10
# Binomial distribution results:
# Heads: 10 | Probability: 1.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Heads: 10 | Probability: 0.000000
# Expected Heads: 0.0
# Expected Tails: 10.0

# %%
import numpy as np
import math
from scipy.stats import stats

n = int(input("Enter n: "))
p = float(input("Enter p: "))
k = int(input("Enter no. of successess you're interested in: "))

def binomial_probability(n, p, k):
    combinations = math.comb(n, k)
    probability = combinations * (p ** k) * ((1-p) ** (n-k))
    return probability

probabilities = []
for k in range(n+1):
    probability = binomial_probability(n, p, k)
    probabilities.append(probability)
    print(f"Heads: {k} | Probability: {probability:.6f"})

expected_heads = n * p
expected_tails = n * (1-p)

print(f"Expected Heads : {expected_heads}")
